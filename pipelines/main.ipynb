# %%
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

# %%
melb_data_path = "melb_data.csv"
melb_test_path = "test.csv" 

melb_read_data = pd.read_csv(melb_data_path, )
melb_test_read = pd.read_csv(melb_test_path, )

melb_read_data.describe()
melb_test_read.head()
# Out:
#      Id  MSSubClass MSZoning LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH          80    11622   Pave   NaN      Reg
# 1  1462          20       RL          81    14267   Pave   NaN      IR1
# 2  1463          60       RL          74    13830   Pave   NaN      IR1
# 3  1464          60       RL          78     9978   Pave   NaN      IR1
# 4  1465         120       RL          43     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
# Train test

melb_read_data.dropna(axis=0, subset=['Price'], inplace=True)

X = melb_read_data

y = melb_read_data.Price

melb_read_data.drop(['Price'], axis=1, inplace=True)

X_train, X_val, y_train, y_val = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=0)

print(X_train.columns.tolist())
print("Test columns:", melb_test_read.columns.tolist())
# Out:
# ['Suburb', 'Address', 'Rooms', 'Type', 'Method', 'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude', 'Longtitude', 'Regionname', 'Propertycount']
# ...

# %%
# Getting means to delete an null columns

categorical_cols = [cname for cname in X_train.columns if
                    X_train[cname].nunique() < 10 and
                    X_train[cname].dtype == 'object']

numerical_cols = [cname for cname in X_train.columns if
                    X_train[cname].dtype in ['int64', 'float64']]

my_cols = categorical_cols + numerical_cols
X_train_fixed = X_train[my_cols].copy()
X_valid_fixed = X_val[my_cols].copy()
# X_test_fixed = melb_test_read[my_cols].copy()

print(melb_test_read)
# Out:
#         Id  MSSubClass MSZoning LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH          80    11622   Pave   NaN      Reg
# 1     1462          20       RL          81    14267   Pave   NaN      IR1
# 2     1463          60       RL          74    13830   Pave   NaN      IR1
# 3     1464          60       RL          78     9978   Pave   NaN      IR1
# 4     1465         120       RL          43     5005   Pave   NaN      IR1
# ...    ...         ...      ...         ...      ...    ...   ...      ...
# 1454  2915         160       RM          21     1936   Pave   NaN      Reg
# 1455  2916         160       RM          21     1894   Pave   NaN      Reg
# 1456  2917          20       RL         160    20000   Pave   NaN      Reg
# 1457  2918          85       RL          62    10441   Pave   NaN      Reg
# 1458  2919          60       RL          74     9627   Pave   NaN      Reg
#
# ...
